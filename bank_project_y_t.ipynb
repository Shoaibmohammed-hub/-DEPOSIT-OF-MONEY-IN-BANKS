# %%
#pymsql

# %%
import mysql.connector
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt


# Connect to server
cnx = mysql.connector.connect(
    host="127.0.0.1",
    port=3306,
    user="root",
    password="12345")

# %%
query = "SELECT * FROM mango.customer"

# %%
df = pd.read_sql(query,cnx)
# Out:
# C:\Users\mansu\AppData\Local\Temp\ipykernel_16680\4203894356.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query,cnx)

# %%
cnx.close()

# %%
df.head(5)
# Out:
#   ï»¿Client ID             Name  Age  Location ID Joined Bank  \
# 0     IND81288    Raymond Mills   24        34324  06-05-2019
# 1     IND65833    Julia Spencer   23        42205  10-12-2001
# 2     IND47499   Stephen Murray   27         7314  25-01-2010
# 3     IND72498   Virginia Garza   40        34594  28-03-2019
# 4     IND60181  Melissa Sanders   46        41269  20-07-2012
#
#     Banking Contact Nationality            Occupation Fee Structure  \
# 0    Anthony Torres    American  Safety Technician IV          High
# 1  Jonathan Hawkins     African   Software Consultant          High
# 2     Anthony Berry    European    Help Desk Operator          High
# 3        Steve Diaz    American          Geologist II           Mid
# 4        Shawn Long    American   Assistant Professor           Mid
#
#   Loyalty Classification  ...  Bank Deposits  Checking Accounts  \
# 0                   Jade  ...     1485828.64          603617.88
# ...

# %%
df. info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ï»¿Client ID              3000 non-null   object
#  1   Name                      3000 non-null   object
#  2   Age                       3000 non-null   int64
#  3   Location ID               3000 non-null   int64
#  4   Joined Bank               3000 non-null   object
#  5   Banking Contact           3000 non-null   object
#  6   Nationality               3000 non-null   object
#  7   Occupation                3000 non-null   object
#  8   Fee Structure             3000 non-null   object
#  9   Loyalty Classification    3000 non-null   object
#  10  Estimated Income          3000 non-null   float64
#  11  Superannuation Savings    3000 non-null   float64
#  12  Amount of Credit Cards    3000 non-null   int64
# ...

# %%
df.describe()
# Out:
#                Age   Location ID  Estimated Income  Superannuation Savings  \
# count  3000.000000   3000.000000       3000.000000             3000.000000
# mean     51.039667  21563.323000     171305.034263            25531.599673
# std      19.854760  12462.273017     111935.808209            16259.950770
# min      17.000000     12.000000      15919.480000             1482.030000
# 25%      34.000000  10803.500000      82906.595000            12513.775000
# 50%      51.000000  21129.500000     142313.480000            22357.355000
# 75%      69.000000  32054.500000     242290.305000            35464.740000
# max      85.000000  43369.000000     522330.260000            75963.900000
#
#        Amount of Credit Cards  Credit Card Balance    Bank Loans  \
# count             3000.000000          3000.000000  3.000000e+03
# mean                 1.463667          3176.206943  5.913862e+05
# std                  0.676387          2497.094709  4.575570e+05
# ...

# %%
df.count()
# Out:
# ï»¿Client ID                3000
# Name                        3000
# Age                         3000
# Location ID                 3000
# Joined Bank                 3000
# Banking Contact             3000
# Nationality                 3000
# Occupation                  3000
# Fee Structure               3000
# Loyalty Classification      3000
# Estimated Income            3000
# Superannuation Savings      3000
# Amount of Credit Cards      3000
# Credit Card Balance         3000
# Bank Loans                  3000
# Bank Deposits               3000
# Checking Accounts           3000
# Saving Accounts             3000
# Foreign Currency Account    3000
# Business Lending            3000
# Properties Owned            3000
# Risk Weighting              3000
# BRId                        3000
# GenderId                    3000
# IAId                        3000
# dtype: int64

# %%
df.shape
# Out:
# (3000, 25)

# %%
df['Estimated Income'].min()
# Out:
# 15919.48

# %%
df['Estimated Income'].max()
# Out:
# 522330.26

# %%
bins = [0,100000,300000,float('inf')]
labels=['Low','Mid','High']
df['Income Band']= pd.cut(df['Estimated Income'],bins=bins,labels=labels,right=False)

# %%
df['Income Band'].value_counts()
# Out:
# Income Band
# Mid     1517
# Low     1027
# High     456
# Name: count, dtype: int64

# %%
df['Income Band'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Income Band'>

# %%
#examine the destribution of unique categories in categorical column
categorical_cols = ["BRId","GenderId","IAId","Amount of Credit Cards","Nationality","Occupation","Fee Structure","Loyalty Classification","Properties Owned","Risk Weighting","Income Band"]
for col in categorical_cols:
    print(f"\nValue Counts for '{col}':")
value_counts=df[col].value_counts()
print (value_counts)
# Out:
# Value Counts for 'BRId':
#
# Value Counts for 'GenderId':
#
# Value Counts for 'IAId':
#
# Value Counts for 'Amount of Credit Cards':
#
# Value Counts for 'Nationality':
#
# Value Counts for 'Occupation':
#
# Value Counts for 'Fee Structure':
#
# Value Counts for 'Loyalty Classification':
#
# Value Counts for 'Properties Owned':
#
# Value Counts for 'Risk Weighting':
#
# Value Counts for 'Income Band':
# Income Band
# Mid     1517
# Low     1027
# High     456
# Name: count, dtype: int64

# %%
    for i, predictor in enumerate(df[["BRId", "GenderId", "IAId", "Amount of Credit Cards", "Nationality",
    "Occupation", "Fee Structure", "Loyalty Classification",
    "Properties Owned", "Risk Weighting", "Income Band"])
        plt.figure(i)
        sns.countplot(data=df, x=predictor, hue= 'Nationality')]
# Out:
#   Cell In[374], line 3
#     "Properties Owned", "Risk Weighting", "Income Band"])
#                                                         ^
# SyntaxError: closing parenthesis ')' does not match opening parenthesis '[' on line 1

# %%
# this process is called BIVARIENTlisting the categporical colunmnof the predicors 
predictor_col= ["BRId", "GenderId", "IAId", "Amount of Credit Cards", "Nationality",
    "Occupation", "Fee Structure", "Loyalty Classification",
    "Properties Owned", "Risk Weighting", "Income Band"]
# now we will find out the each p[redictor and plot againts the nationality 

for i, predictor in enumerate(predictor_col):
    plt.figure(figsize=(8,6))
    sns.countplot(data=df, x=predictor, hue='GenderId')
    plt.title(f'{predictor} by GenderId')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

# %%
#UNIVARIENT
predictor_col= ["BRId", "GenderId", "IAId", "Amount of Credit Cards", "Nationality",
    "Occupation", "Fee Structure", "Loyalty Classification",
    "Properties Owned", "Risk Weighting", "Income Band"]
#Puting the Loop statement 
for predictor in predictor_col:
    plt.figure(figsize=(8,6))
    sns.countplot(data=df,x=predictor)
    plt.title(f'Distribution of {predictor}')
    plt.tight_layout()
    plt.xticks(rotation=45)
    plt.show()

# %%
 # Histoplot of value counts for the diffrent Occupation
import matplotlib.pyplot as plt
import seaborn as sns
categorical_col = df
for col in categorical_col:
    if col == "Occupation":
        continue
        plt.figure(figsize(4,8))
        sns.histplot(df[col])
        plt.title(f'histogram of the occupation counts')
        plt.xticks(rotation = 45)
        plt.xlabel(col)
        plt.ylabel("no of counts")
        plt.tight_layout()
        plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Define categorical columns
categorical_col = df.select_dtypes(include='object').columns.tolist()

# Loop through and plot
for col in categorical_col:
    if col == "Occupation":
        continue
    plt.figure(figsize=(25, 15))
    sns.histplot(data=df, x="Occupation", stat="count", discrete=True)
    plt.title(f'Count Plot of {col}')
    plt.xlabel(col)
    plt.ylabel("Count")
    plt.show()

# %%
#HISTOPLOT of the value count for different occupation 
import seaborn as sns
import matplotlib.pyplot as plt
categorical_col=df.columns
for col in categorical_cols:
   if col == "Occupation":
       continue
       plt.figure(figsize(8,4))
       sns.histoplot(df[col])
       plt.title('Histogram of occupation Count')
       plt.xlabel(col)
       plt.ylabel("count")
       plt.show()

# %%
# numerical Annalyiss 
numerical_cols =['Estimated Income','Superannuation Savings']
#Heer we will be doing the univarient analysis
plt.figure(figsize=(10,6))
for i,col in enumerate(numerical_cols):
    plt.subplot(2, 1, i+1)
    sns.histplot(df[col],kde=True)
    plt.xlabel(col)
    plt.ylabel('frequency')
    plt.title(f'charts')
    plt.tight_layout()
    plt.show()

# %%
# doinf the numericak analysis onnevery numerical values in the csv files 
import seaborn as sns 
import matplotlib.pyplot as plt
#tryinggto get the univarient ananlysis 
numerical_cols = ['Estimated Income','Superannuation Savings','Location ID','Age','Credit Card Balance','Bank Loans','Bank Deposits','Checking Accounts','Saving Accounts','Foreign Currency Account','Business Lending']
#geting in the figure size s
plt.figure(figsize=(15,10))
for i, col in enumerate(numerical_cols):
    plt.subplot(4,3,i+1)
    sns.histplot(df[col],kde=True)
    plt.title(col)
    plt.tight_layout()
    plt.show()

# %%
# now we will perform the Heatmap
numerical_cols = ['Estimated Income','Superannuation Savings','Location ID','Age','Credit Card Balance','Bank Loans','Bank Deposits','Checking Accounts','Saving Accounts','Foreign Currency Account','Business Lending']
correlation_matrix = df[numerical_col].corr()
plt.figure(figsize=(12,12))
sns.heatmap(correlation_matrix, annot=True , cmap='crest', fmt=".1f")
plt.title('corelastion Mrtrix')
plt.xticks(rotatioin = 45, ha='right')
plt.yticks(rotation =0)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[567], line 7
#       5 sns.heatmap(correlation_matrix, annot=True , cmap='crest', fmt=".1f")
#       6 plt.title('corelastion Mrtrix')
# ----> 7 plt.xticks(rotatioin = 45, ha='right')
#       8 plt.yticks(rotation =0)
#       9 plt.tight_layout()
#
# File ~\anaconda3\Lib\site-packages\matplotlib\pyplot.py:2227, in xticks(ticks, labels, minor, **kwargs)
#    2225     labels_out = ax.get_xticklabels(minor=minor)
#    2226     for l in labels_out:
# -> 2227         l._internal_update(kwargs)
#    2228 else:
#    2229     labels_out = ax.set_xticklabels(labels, minor=minor, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\matplotlib\artist.py:1216, in Artist._internal_update(self, kwargs)
#    1209 def _internal_update(self, kwargs):
#    1210     """
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Define the correct column list
numerical_cols = [
    'Estimated Income', 'Superannuation Savings', 'Location ID', 'Age',
    'Credit Card Balance', 'Bank Loans', 'Bank Deposits', 'Checking Accounts',
    'Saving Accounts', 'Foreign Currency Account', 'Business Lending'
]

correlation_matrix = df[numerical_cols].corr()

#now im doing the heatmampplotting 
plt.figure(figsize=(12,12))
sns.heatmap(correlation_matrix, annot=True, cmap='crest',fmt=".1f")
plt.title('correlation matrix')
plt.xticks(rotation=45,ha='right')
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
#insights of the Eda 
#the strongest positive correlation occur among the "bank deposit" with checking account and saving account
#the customers who are

# %%
sns.heatmap(correlation_matrix)
# Out:
# <Axes: >
